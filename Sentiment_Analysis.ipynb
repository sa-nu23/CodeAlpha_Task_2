# %%
import pandas as pd

# Sample review dataset
data = {
    'Review': [
        "This product is amazing! I love it.",
        "Terrible experience, I want a refund.",
        "It's okay, not bad but not great either.",
        "Absolutely fantastic quality and service!",
        "Worst purchase ever. Completely useless.",
        "Meh... it's average.",
        "Exceeded my expectations!",
        "Not worth the money at all.",
        "Very satisfied with the product.",
        "I don’t like it, but it’s not terrible."
    ]
}

df = pd.DataFrame(data)

# %%
from textblob import TextBlob

# Function to classify sentiment
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    if polarity > 0.1:
        return 'Positive'
    elif polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# Apply function
df['Sentiment'] = df['Review'].apply(get_sentiment)
df
# Out:
#                                       Review Sentiment
# 0        This product is amazing! I love it.  Positive
# 1      Terrible experience, I want a refund.  Negative
# 2   It's okay, not bad but not great either.  Positive
# 3  Absolutely fantastic quality and service!  Positive
# 4   Worst purchase ever. Completely useless.  Negative
# 5                       Meh... it's average.  Negative
# 6                  Exceeded my expectations!   Neutral
# 7                Not worth the money at all.  Negative
# 8           Very satisfied with the product.  Positive
# 9    I don’t like it, but it’s not terrible.  Positive

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Sentiment', data=df, palette='Set2')
plt.title('Sentiment Distribution of Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2263049618.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment', data=df, palette='Set2')

# %%
from nrclex import NRCLex

# Detect dominant emotion
def detect_emotion(text):
    emotions = NRCLex(text).raw_emotion_scores
    return max(emotions, key=emotions.get) if emotions else 'None'

df['Dominant Emotion'] = df['Review'].apply(detect_emotion)
df[['Review', 'Sentiment', 'Dominant Emotion']]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/textblob/decorators.py in decorated(*args, **kwargs)
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as error:
#
# /usr/local/lib/python3.12/dist-packages/textblob/tokenizers.py in tokenize(self, text)
#      59         """Return a list of sentences."""
# ---> 60         return nltk.tokenize.sent_tokenize(text)
#      61
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     104     """
# --> 105     return PunktTokenizer(language)
#     106
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/punkt.py in __init__(self, lang)
#    1743         PunktSentenceTokenizer.__init__(self)
# -> 1744         self.load_lang(lang)
#    1745
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/punkt.py in load_lang(self, lang)
#    1748
# -> 1749         lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1750         self._params = load_punkt_params(lang_dir)
#
# /usr/local/lib/python3.12/dist-packages/nltk/data.py in find(resource_name, paths)
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#
# LookupError:
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# The above exception was the direct cause of the following exception:
#
# MissingCorpusError                        Traceback (most recent call last)
# /tmp/ipython-input-3171844366.py in <cell line: 0>()
#       6     return max(emotions, key=emotions.get) if emotions else 'None'
#       7
# ----> 8 df['Dominant Emotion'] = df['Review'].apply(detect_emotion)
#       9 df[['Review', 'Sentiment', 'Dominant Emotion']]
#      10
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipython-input-3171844366.py in detect_emotion(text)
#       3 # Detect dominant emotion
#       4 def detect_emotion(text):
# ----> 5     emotions = NRCLex(text).raw_emotion_scores
#       6     return max(emotions, key=emotions.get) if emotions else 'None'
#       7
#
# /usr/local/lib/python3.12/dist-packages/nrclex.py in __init__(self, text)
#    2871         self.text = text
#    2872         blob = TextBlob(text)
# -> 2873         self.words = list(blob.words)
#    2874         self.sentences = list(blob.sentences)
#    2875         build_word_affect(self)
#
# /usr/local/lib/python3.12/dist-packages/textblob/decorators.py in __get__(self, obj, cls)
#      21         if obj is None:
#      22             return self
# ---> 23         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      24         return value
#      25
#
# /usr/local/lib/python3.12/dist-packages/textblob/blob.py in words(self)
#     623         :returns: A :class:`WordList <WordList>` of word tokens.
#     624         """
# --> 625         return WordList(word_tokenize(self.raw, include_punc=False))
#     626
#     627     @property
#
# /usr/local/lib/python3.12/dist-packages/textblob/tokenizers.py in word_tokenize(text, include_punc, *args, **kwargs)
#      75     words = chain.from_iterable(
#      76         _word_tokenizer.itokenize(sentence, include_punc, *args, **kwargs)
# ---> 77         for sentence in sent_tokenize(text)
#      78     )
#      79     return words
#
# /usr/local/lib/python3.12/dist-packages/textblob/base.py in itokenize(self, text, *args, **kwargs)
#      66         :rtype: generator
#      67         """
# ---> 68         return (t for t in self.tokenize(text, *args, **kwargs))
#      69
#      70
#
# /usr/local/lib/python3.12/dist-packages/textblob/decorators.py in decorated(*args, **kwargs)
#      35             return func(*args, **kwargs)
#      36         except LookupError as error:
# ---> 37             raise MissingCorpusError() from error
#      38
#      39     return decorated
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.
